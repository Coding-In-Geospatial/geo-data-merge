# %% [markdown]
# # Geo-spatial data creation

# %% [markdown]
# **The aim is to obtain Africa data from corona CSV and merge with World geojson**
#
# Libraries are pandas and Geopandas
#
# Pandas - for statistical analysis
# Geopandas - for geospatial statistical

# %%
import pandas as pd

import geopandas as gpd

# %% [markdown]
# **we will use :**
#
# 1. confirmed corona cases from John Hopkins University GitHub repository
#
# 2. World geoJson shapefile
#
# 3. CSV file with continents name

# %%
confirmed = r'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

data_cont =  r'https://raw.githubusercontent.com/oderofrancis/rona/main/Countries-Continents.csv'

world = r'https://raw.githubusercontent.com/oderofrancis/africa-corona/main/world.geojson'

# %% [markdown]
# Reading all data using pandas and geopandas

# %%
confirmed = pd.read_csv(confirmed)

data_cont = pd.read_csv(data_cont)

world = gpd.read_file(world)

# %% [markdown]
# Data tables and columns

# %%
confirmed.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Province/State</th>
#       <th>Country/Region</th>
#       <th>Lat</th>
#       <th>Long</th>
#       <th>1/22/20</th>
#       <th>1/23/20</th>
#       <th>1/24/20</th>
#       <th>1/25/20</th>
#       <th>1/26/20</th>
#       <th>1/27/20</th>
#       <th>...</th>
#       <th>6/29/22</th>
#       <th>6/30/22</th>
#       <th>7/1/22</th>
#       <th>7/2/22</th>
#       <th>7/3/22</th>
#       <th>7/4/22</th>
#       <th>7/5/22</th>
#       <th>7/6/22</th>
#       <th>7/7/22</th>
#       <th>7/8/22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>Afghanistan</td>
#       <td>33.93911</td>
#       <td>67.709953</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>182403</td>
#       <td>182528</td>
#       <td>182594</td>
#       <td>182643</td>
#       <td>182724</td>
#       <td>182793</td>
#       <td>182793</td>
#       <td>182979</td>
#       <td>183084</td>
#       <td>183221</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>Albania</td>
#       <td>41.15330</td>
#       <td>20.168300</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>280298</td>
#       <td>280851</td>
#       <td>281470</td>
#       <td>282141</td>
#       <td>282690</td>
#       <td>282690</td>
#       <td>282690</td>
#       <td>283811</td>
#       <td>284758</td>
#       <td>285731</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>Algeria</td>
#       <td>28.03390</td>
#       <td>1.659600</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>266073</td>
#       <td>266087</td>
#       <td>266105</td>
#       <td>266115</td>
#       <td>266128</td>
#       <td>266173</td>
#       <td>266173</td>
#       <td>266181</td>
#       <td>266202</td>
#       <td>266228</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>Andorra</td>
#       <td>42.50630</td>
#       <td>1.521800</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>43774</td>
#       <td>43774</td>
#       <td>44177</td>
#       <td>44177</td>
#       <td>44177</td>
#       <td>44177</td>
#       <td>44177</td>
#       <td>44671</td>
#       <td>44671</td>
#       <td>44671</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>Angola</td>
#       <td>-11.20270</td>
#       <td>17.873900</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#       <td>101320</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 903 columns</p>
# </div>

# %%
data_cont.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Continent</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa</td>
#       <td>Algeria</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa</td>
#       <td>Angola</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa</td>
#       <td>Benin</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa</td>
#       <td>Botswana</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa</td>
#       <td>Burkina Faso</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
world.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>UN</th>
#       <th>NAME</th>
#       <th>LON</th>
#       <th>LAT</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>28</td>
#       <td>Antigua and Barbuda</td>
#       <td>-61.783</td>
#       <td>17.078</td>
#       <td>MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12</td>
#       <td>Algeria</td>
#       <td>2.632</td>
#       <td>28.163</td>
#       <td>MULTIPOLYGON (((2.96361 36.80222, 2.98139 36.8...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>31</td>
#       <td>Azerbaijan</td>
#       <td>47.395</td>
#       <td>40.430</td>
#       <td>MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>Albania</td>
#       <td>20.068</td>
#       <td>41.143</td>
#       <td>MULTIPOLYGON (((19.43621 41.02107, 19.45055 41...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>51</td>
#       <td>Armenia</td>
#       <td>44.563</td>
#       <td>40.534</td>
#       <td>MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
world.plot(figsize=(20,10),cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **Data analysis**

# %%
data_con = confirmed[['Country/Region',confirmed.columns[-1]]]

data_con.columns = ['country','confirmed']

data_cont.columns = ['continent','country']

world = world[['NAME', 'geometry']]

world.columns = ['country','geometry']

# %% [markdown]
# **Data merging**

# %%
data_con = pd.merge(left=data_cont, 
                right=data_con, how='left', 
                left_on='country', right_on='country'
            )

# %%
data_con.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>country</th>
#       <th>confirmed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa</td>
#       <td>Algeria</td>
#       <td>266228.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa</td>
#       <td>Angola</td>
#       <td>101320.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa</td>
#       <td>Benin</td>
#       <td>27216.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa</td>
#       <td>Botswana</td>
#       <td>324154.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa</td>
#       <td>Burkina Faso</td>
#       <td>21044.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# **Data merging with geojson**

# %%
geo_data_con = pd.merge(left=data_con, 
                right=world, how='left', 
                left_on='country', right_on='country'
            )


geo_data_con = gpd.GeoDataFrame(geo_data_con)

# %%
geo_data_con.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>country</th>
#       <th>confirmed</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa</td>
#       <td>Algeria</td>
#       <td>266228.0</td>
#       <td>MULTIPOLYGON (((2.96361 36.80222, 2.98139 36.8...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa</td>
#       <td>Angola</td>
#       <td>101320.0</td>
#       <td>MULTIPOLYGON (((11.75083 -16.75528, 11.77500 -...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa</td>
#       <td>Benin</td>
#       <td>27216.0</td>
#       <td>MULTIPOLYGON (((2.48442 6.34049, 2.48000 6.338...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa</td>
#       <td>Botswana</td>
#       <td>324154.0</td>
#       <td>MULTIPOLYGON (((26.95919 -23.75208, 26.96331 -...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa</td>
#       <td>Burkina Faso</td>
#       <td>21044.0</td>
#       <td>MULTIPOLYGON (((-2.83405 11.00201, -2.83361 10...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_africa = geo_data_con[geo_data_con['continent'] == 'Africa']

# %%
data_africa.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>country</th>
#       <th>confirmed</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa</td>
#       <td>Algeria</td>
#       <td>266228.0</td>
#       <td>MULTIPOLYGON (((2.96361 36.80222, 2.98139 36.8...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa</td>
#       <td>Angola</td>
#       <td>101320.0</td>
#       <td>MULTIPOLYGON (((11.75083 -16.75528, 11.77500 -...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa</td>
#       <td>Benin</td>
#       <td>27216.0</td>
#       <td>MULTIPOLYGON (((2.48442 6.34049, 2.48000 6.338...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa</td>
#       <td>Botswana</td>
#       <td>324154.0</td>
#       <td>MULTIPOLYGON (((26.95919 -23.75208, 26.96331 -...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa</td>
#       <td>Burkina Faso</td>
#       <td>21044.0</td>
#       <td>MULTIPOLYGON (((-2.83405 11.00201, -2.83361 10...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
len(data_africa)
# Out:
# 54

# %%
data_africa.sort_values(by='confirmed',ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>continent</th>
#       <th>country</th>
#       <th>confirmed</th>
#       <th>geometry</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>44</th>
#       <td>Africa</td>
#       <td>South Africa</td>
#       <td>3997269.0</td>
#       <td>MULTIPOLYGON (((37.85083 -46.95695, 37.84638 -...</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Africa</td>
#       <td>Morocco</td>
#       <td>1238371.0</td>
#       <td>MULTIPOLYGON (((-9.05317 32.73480, -9.03500 32...</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Africa</td>
#       <td>Tunisia</td>
#       <td>1066127.0</td>
#       <td>MULTIPOLYGON (((10.99361 33.75000, 10.93778 33...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Africa</td>
#       <td>Egypt</td>
#       <td>515645.0</td>
#       <td>MULTIPOLYGON (((34.00139 26.70722, 33.99667 26...</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Africa</td>
#       <td>Libya</td>
#       <td>502189.0</td>
#       <td>MULTIPOLYGON (((9.94833 27.82444, 9.95417 27.8...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data_africa.plot(figsize=(10,15),column='confirmed',
                  legend=True,
                    legend_kwds={'label': "Confirmed cases by Country",
                                 'orientation': "horizontal"}
                 )
# Out:
# <AxesSubplot:>
